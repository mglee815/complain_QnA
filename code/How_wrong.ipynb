# %%
import pandas as pd

# %%
data = pd.read_pickle("../data/sample5_df.pkl")

# %%
data
# Out:
#                                                        제목  \
# 0                                   농산물(한방재) 부재료의 중량표시 방법
# 1                                        전문건설업간 하도급계약에 관련
# 2             녹색건축 예비인증 후 설계변경시 예비인증을 다시 받아야 하는 경우에 관한 질의
# 3                                   상수도사용 및 배수로침수 해결바랍니다
# 4        (SPP-1803-1600277)임대아파트의 에어컨 실외기 문제로 호소합니다. 저는 임
# ...                                                   ...
# 426249                                          의료법 위반 민원
# 426250                    청파동3가 134-47외 3필지 신축으로 인한 피해 진정
# 426251             고덕아르테온 관리업체 선정과정의 부당함에 대한 감사 및 행정지도 요청
# 426252  [서울스마트불편신고(앱)]빌딩 숲 사이에 흡연 장소는 없고 하다보니 다들 골목에 모...
# 426253               [120문자신고 접수]서울 강동구 양재대로112길 13 (진...
#
#                                                        본문  민원발생지  \
# 0       안녕하십니까! 수고많으십니다.\r\n\r\n농산물(부재료)에 대한 중량표시 및 오차...   전라북도
# 1       안녕하세요 저는 서울에서 일반토목공사를 하는 현장소장입니다.\r\n다름이 아니라 \...    경기도
# 2       1. 녹색건축 예비인증을 받은 이후에 각각 아래 1)에서 4)와 같은 설계변경 또는...    경기도
# ...

# %%
data = data[['접수기관', '처리부서']]

# %%
TF = data.apply(lambda x : str(x['접수기관']) not in str(x['처리부서']), axis = 1)

# %%
data[TF]
# Out:
#             접수기관                        처리부서
# 167     인천광역시 남구    인천광역시 미추홀구 지속가능도시국 도시정비과
# 206        보건복지부       질병관리청 감염병정책국 감염병정책총괄과
# 209        보건복지부       질병관리청 감염병정책국 감염병정책총괄과
# 392        보건복지부       질병관리청 의료안전예방국 의료감염관리과
# 473     인천광역시 남구  인천광역시 미추홀구 사회경제복지국 기초생활보장과
# ...          ...                         ...
# 253725     보건복지부      질병관리청 감염병위기대응국 위기대응총괄과
# 312917     서울특별시                         NaN
# 330550     서울특별시                         NaN
# 374300     서울특별시                         NaN
# 376627     서울특별시                         NaN
#
# [1384 rows x 2 columns]
